# %% [markdown]
# ## **Read Me**
# This dataset comprises 981 accessions characterized by 10 morphological traits, curated and conserved by the AfricaRice Genebank as of September 2021. The data were originally downloaded from Genesys-PGR, an open-source platform for plant genetic resources.
#
# **Species Included**
# Oryza sativa L. and Oryza glaberrima Steud.
#
# **raits Evaluated**
# Ten morphological/agronomic traits were evaluated (see documentation or dataset header for details).
#
# **License**
# This dataset is distributed under the Creative Commons CC BY-NC license.
# You are free to use, adapt, and share this data for non-commercial purposes, provided proper attribution is given.

# %% [markdown]
# ### **Traits observed**
# **Plant Type**
#
# Culm Angle - rice direct-seeded in rows.
#
# **Leaf blade length**
#
# Measure the highest leaf below the flag leaf (penultimate leaf) on the main culm from the ligule to the tip of the blade on five representative plants. Calculate average to nearest centimeter.
#
# **Leaf blade width**
#
# Measure at the widest portion of the penultimate leaf (i.e. highest leaf below the flag leaf) on the main culm on five representative plants. Calculate average to nearest cm. Oryza sativa leaf can be coded as narrow (< 1 cm), internediate (1-2 cm) or broad (>2 cm).
#
# **Panicle length**
#
# Length of main axis of panicle measured from the panicle base to the tip. Record the average of five representative plants. Stage: 7 days after anthesis or upon full panicle exsertion.
#
# **Ligule length**
#
# Ligule length in millimeter
#
# **Ligule Shape**
#
# **Ligule shape**
#
# **Culm Diameter**
#
# Culm diameter of basal internode at reproductive in millimeter
#
# **Culm length**
#
# Measured from ground level to the base of the panicle. Record the average of five actual measurements, to the nearest cm.
#
# **Total number of tillers**
#
# Count tillers with panicles and those without panicles on 5 samples
#
# **Number of fertile tillers**
#
# Count only the tillers with panicles on 5 samples.

# %% [markdown]
# **Contributors**
#
# Data Manager: Tohoun Romeo (AfricaRice Center)
#
# Data Collector: Sedjro Bienvenu Kpeki (AfricaRice Center)
#
# Data Curator: Marie Noelle Ndjiondjop (AfricaRice Center)
#
# **Citation**
#
# If you use this dataset in your work, please cite the source accordingly and acknowledge AfricaRice and Genesys-PGR.
#
# **Contact**
# For questions, suggestions or collaborations, please contact:
#
# Valdenilson Felipe P. da Silva
#
# Universidade Federal de São Carlos
#
# Email: Valdenilsonfps@estudante.ufscar.br
#
# GitHub: Valdenilson-F

# %% [markdown]
# ## **The analisys:**

# %% [markdown]
# import the libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.stats import pearsonr

# %% [markdown]
# uploading data:

# %%
data=pd.read_csv('Data/Data.csv')

# %% [markdown]
# confering traits of columns:

# %%
data
# Out:
#      Acc.Number Leaf blade length [cm] Leaf blade width [cm] Culm length [cm]  \
# 0    WAB0000089                  14,35                  1,00            64,00
# 1    WAB0000157                  34,58                  1,93           124,72
# 2    WAB0000169                  31,96                  1,30            82,50
# 3    WAB0000189                  42,33                  1,60           108,08
# 4    WAB0000209                  37,44                  1,62           116,21
# ..          ...                    ...                   ...              ...
# 976  WAB0038918                  30,62                  1,80            97,04
# 977  WAB0038920                  30,68                  1,73            90,00
# 978  WAB0038928                  36,30                  1,40           128,87
# 979  WAB0012167                  34,20                  1,80           103,67
# 980  WAB0038950                  30,06                  1,90           117,67
#
#     Panicle length [cm] Ligule length [mm] Culm diameter [mm]  \
# 0                 17,50               0,50               6,20
# 1                 25,40               0,59               0,61
# 2                 17,67               1,77               5,73
# 3                 27,73                NaN                NaN
# 4                 27,08                NaN               5,00
# ..                  ...                ...                ...
# 976               25,27               1,68               3,50
# 977               24,60               1,83               7,43
# 978               32,13                NaN                NaN
# 979               27,27                NaN                NaN
# 980               27,47               1,50               8,47
#
#      Total number of tillers   Number of fertile tillers   \
# 0                         2.0                         1.0
# 1                        40.0                        28.0
# 2                        13.0                        12.0
# 3                        15.0                        17.0
# 4                        44.0                        16.0
# ..                        ...                         ...
# 976                      17.0                        16.0
# 977                      14.0                        13.0
# 978                      13.0                        10.0
# 979                       6.0                         5.0
# 980                       7.0                         6.0
#
#             Ligule Shape Plant Type
# 0                  CLEFT      ERECT
# 1                    NaN        NaN
# 2    ACUTE TO ACCUMUNATE      ERECT
# 3                    NaN        NaN
# 4                    NaN        NaN
# ..                   ...        ...
# 976                  NaN        NaN
# 977  ACUTE TO ACCUMUNATE      ERECT
# 978                  NaN        NaN
# 979                  NaN        NaN
# 980                CLEFT      ERECT
#
# [981 rows x 11 columns]

# %% [markdown]
# checking our data it is possible to see that some columns have a comma to separate the decimals and this will make them be read as a string

# %%
data.describe()
# Out:
#        Total number of tillers   Number of fertile tillers
# count                977.000000                  974.000000
# mean                  18.561924                   14.362423
# std                   10.176441                    7.662529
# min                    2.000000                    1.000000
# 25%                   12.000000                   10.000000
# 50%                   16.000000                   13.000000
# 75%                   22.000000                   17.000000
# max                   96.000000                   72.000000

# %% [markdown]
# then we will select the numeric columns of the dataframe and then apply the following code:

# %%
cols= ['Leaf blade length [cm]', 'Leaf blade width [cm]',
       'Culm length [cm]', 'Panicle length [cm]', 'Ligule length [mm]',
       'Culm diameter [mm]','Total number of tillers ', 'Number of fertile tillers ']

data[cols]=data[cols].replace(',','.', regex=True)
data[cols]=data[cols].astype(float)

# %% [markdown]
# when describing our data again you can see that it selects all the numeric columns now

# %%
data.describe()
# Out:
#        Leaf blade length [cm]  Leaf blade width [cm]  Culm length [cm]  \
# count              973.000000             867.000000        976.000000
# mean                36.831161               1.500531        114.748709
# std                  9.639867               0.365949         22.839794
# min                 10.150000               0.100000         52.000000
# 25%                 30.680000               1.230000         99.280000
# 50%                 37.330000               1.530000        118.055000
# 75%                 42.740000               1.730000        129.550000
# max                 95.060000               4.070000        188.530000
#
#        Panicle length [cm]  Ligule length [mm]  Culm diameter [mm]  \
# count           971.000000          512.000000          762.000000
# mean             26.549609            1.585645            3.978780
# std               3.077160            0.700308            2.820466
# min              15.300000            0.200000            0.500000
# 25%              24.600000            1.200000            0.580000
# 50%              26.540000            1.600000            4.815000
# 75%              28.545000            1.930000            6.365000
# max              38.400000            6.830000            9.600000
#
#        Total number of tillers   Number of fertile tillers
# count                977.000000                  974.000000
# mean                  18.561924                   14.362423
# std                   10.176441                    7.662529
# min                    2.000000                    1.000000
# 25%                   12.000000                   10.000000
# 50%                   16.000000                   13.000000
# 75%                   22.000000                   17.000000
# max                   96.000000                   72.000000

# %% [markdown]
# At this point we need to transform the columns of our interest into a dataframe to create our graphs without major problems.

# %%
df=data[cols]
df = df.apply(pd.to_numeric, errors='coerce')
df
# Out:
#      Leaf blade length [cm]  Leaf blade width [cm]  Culm length [cm]  \
# 0                     14.35                   1.00             64.00
# 1                     34.58                   1.93            124.72
# 2                     31.96                   1.30             82.50
# 3                     42.33                   1.60            108.08
# 4                     37.44                   1.62            116.21
# ..                      ...                    ...               ...
# 976                   30.62                   1.80             97.04
# 977                   30.68                   1.73             90.00
# 978                   36.30                   1.40            128.87
# 979                   34.20                   1.80            103.67
# 980                   30.06                   1.90            117.67
#
#      Panicle length [cm]  Ligule length [mm]  Culm diameter [mm]  \
# 0                  17.50                0.50                6.20
# 1                  25.40                0.59                0.61
# 2                  17.67                1.77                5.73
# 3                  27.73                 NaN                 NaN
# 4                  27.08                 NaN                5.00
# ..                   ...                 ...                 ...
# 976                25.27                1.68                3.50
# 977                24.60                1.83                7.43
# 978                32.13                 NaN                 NaN
# 979                27.27                 NaN                 NaN
# 980                27.47                1.50                8.47
#
#      Total number of tillers   Number of fertile tillers
# 0                         2.0                         1.0
# 1                        40.0                        28.0
# 2                        13.0                        12.0
# 3                        15.0                        17.0
# 4                        44.0                        16.0
# ..                        ...                         ...
# 976                      17.0                        16.0
# 977                      14.0                        13.0
# 978                      13.0                        10.0
# 979                       6.0                         5.0
# 980                       7.0                         6.0
#
# [981 rows x 8 columns]

# %% [markdown]
# It is always very interesting at the beginning of a multivariate analysis to apply point data to check the distribution of the data, see outliers and predictability.

# %%
sns.pairplot(data[cols], diag_kind='kde')
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# A quick look at this matrix of graphs shows how the relationship between "Total number of tillers" and "Number of fertile tillers" distributes its values ​​around an imaginary curve, which is a clear sign that the data is correlated.
#
# If in doubt, you can apply Pearson's correlation

# %%
corr, pval = pearsonr(df['Total number of tillers '], df['Number of fertile tillers '])
print(f"Pearson correlation: {corr:.2f} (p-value: {pval:.6f})")
# Out:
# Pearson correlation: nan (p-value: nan)

# %% [markdown]
# We can see that they have a positive correlation (if one increases the other increases too) of 77% and a p-value of 0 (meaning that there is no probability of this being due to chance)

# %%
df = data[['Total number of tillers ', 'Number of fertile tillers ']].dropna()

sns.jointplot(
    data=df,
    x='Total number of tillers ', 
    y='Number of fertile tillers ',
    kind='reg',
    scatter_kws={'alpha':0.3, 'color':'#6666ff'},
    line_kws={'color':'#FF4D00', 'linewidth':1},
    
    
)

plt.xlabel('Total number of tillers ')
plt.xticks(np.arange(0,90,10))
plt.ylabel('Number of fertile tillers ')
plt.yticks(np.arange(0,110,10))
plt.grid(True, zorder=1)
plt.suptitle('Relationship between Vegetative Capacity and Productive Potential', fontsize=14)
plt.show()

# %% [markdown]
# When viewing the information in this graph, it becomes intuitive to see that rice reaches its maximum production capacity between 10-20 seeds, as this is where maximum vegetative use is concentrated.

# %% [markdown]
# based on this, we can ask ourselves 'what other characteristics are correlated' and we can create a 'heatmap' that answers us graphically

# %%
df=data[cols]
df = df.apply(pd.to_numeric, errors='coerce')
df.dropna(axis=0, inplace=True)
df
# Out:
#      Leaf blade length [cm]  Leaf blade width [cm]  Culm length [cm]  \
# 0                     14.35                   1.00             64.00
# 1                     34.58                   1.93            124.72
# 2                     31.96                   1.30             82.50
# 5                     32.58                   1.07             81.10
# 10                    25.16                   0.97             67.67
# ..                      ...                    ...               ...
# 974                   37.32                   1.57            112.67
# 975                   31.00                   2.00            107.00
# 976                   30.62                   1.80             97.04
# 977                   30.68                   1.73             90.00
# 980                   30.06                   1.90            117.67
#
#      Panicle length [cm]  Ligule length [mm]  Culm diameter [mm]  \
# 0                  17.50                0.50                6.20
# 1                  25.40                0.59                0.61
# 2                  17.67                1.77                5.73
# 5                  32.17                2.10                7.13
# 10                 28.23                1.40                6.13
# ..                   ...                 ...                 ...
# 974                29.23                2.20                5.30
# 975                24.40                2.10                7.00
# 976                25.27                1.68                3.50
# 977                24.60                1.83                7.43
# 980                27.47                1.50                8.47
#
#      Total number of tillers   Number of fertile tillers
# 0                         2.0                         1.0
# 1                        40.0                        28.0
# 2                        13.0                        12.0
# 5                        28.0                        26.0
# 10                       12.0                        10.0
# ..                        ...                         ...
# 974                      12.0                        11.0
# 975                       5.0                         4.0
# 976                      17.0                        16.0
# 977                      14.0                        13.0
# 980                       7.0                         6.0
#
# [450 rows x 8 columns]

# %%
pearson_corr=df.corr(method='pearson')

sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', center=0)
plt.title("Pearson's correlation for the characteristics of Oryza sativa")
plt.show()

# %% [markdown]
# Among the other characteristics that have a strong positive correlation, we can highlight 'culm length (cm)' with 'Leaf blade length (cm), 'leaf blade width (cm)' with 'leaf blade length (cm)' and 'culm length (cm) with leaf blade width (cm)'.
#
# This leads us to the next notes, as if by the Simpsons paradox, if together these analyzed characteristics can present a distinct correlation.

# %% [markdown]
# Now we can perform the moment we use machine learning using the sklearn library where we have several resources to model results based on our data.

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# First, we need to list the columns (X) that we will use to predict the result we want (y).
#
# We must also remember that only numerical results are listed here.

# %%
X=df[['Leaf blade length [cm]', 'Leaf blade width [cm]', 'Culm length [cm]',
       'Panicle length [cm]', 'Ligule length [mm]', 'Culm diameter [mm]',
       'Total number of tillers ']]
y=df['Number of fertile tillers ']

# %% [markdown]
# We separate 30% of the data to test and verify if our predictions work with the size of our dataframe and if this information is enough to predict 'y'

# %%
# Suponha que X sejam os dados de entrada e y os rótulos/valores alvo
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %% [markdown]
# We will be using a simple linear regression

# %%
lm=linear_model.LinearRegression()

# %% [markdown]
# we can check the size of the data we used to train the model with the '.shape' command and we see that 315 rows were used

# %%
X_train.shape, y_train.shape
# Out:
# ((315, 7), (315,))

# %% [markdown]
# we train the model and see the predictions that 'X_test' predicted

# %%
lm.fit(X_train,y_train)
pred = lm.predict(X_test)
pred.shape
# Out:
# (135,)

# %% [markdown]
# the 'lm.score' command gives us the variation of the data, with values ​​closer to 1 it means that the model explains well, with a value equal to 0.5 it is as predictable as if it were guessed by chance, a value of 0 means that the model does not explain any of the data

# %%
lm.score(X_train,y_train)
# Out:
# 0.8007573582293553

# %% [markdown]
# However, 'lm.score' is not ideal because it tells us percentages and not values ​​of our variable. For this we can use RMSE, the root mean square error, which shows us how much our model varies from the observations in terms of numbers of our variable.
#
# Here 3.12 seeds

# %%
mse = mean_squared_error(y_test, pred)
rmse=np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 3.127175126065209

# %% [markdown]
# We can plot this on a graph and see more clearly that as we increase the number of fertile profiles we can see that there is a greater error
#
# and where the data is more reliable, between 10 and 20 profiles

# %%
# Certifique-se de que y_teste e y_pred sejam arrays numpy
y_teste = np.array(y_test)
y_pred = np.array(pred)

plt.figure(figsize=(6, 6))

# Plotagem principal
sns.regplot(
    x=y_test, 
    y=pred, 
    scatter_kws={'alpha': 0.3, 'color': '#6666ff'},
    line_kws={'color': '#FF4D00', 'linewidth': 1}
)

# Linha de 45 graus
plt.plot([y_teste.min(), y_teste.max()], [y_teste.min(), y_teste.max()], 'g--', label='Linha 45° (y = x)')

# Adicionando as distâncias perpendiculares (resíduos visuais)
for xi, yi in zip(y_teste, y_pred):
    # Projetar ponto (xi, yi) na reta y = x
    proj = (xi + yi) / 2
    plt.plot([xi, proj], [yi, proj], 'gray', alpha=0.5)

plt.xlabel("Número observado de perfilhos férteis (y_teste)")
plt.ylabel("Número previsto de perfilhos férteis (ŷ)")
plt.title("Validação da Regressão Linear em Oryza spp.")
plt.grid(True)
plt.axis("equal")
plt.legend()
plt.show()

# %% [markdown]
# we can summarize everything that was seen by importing the 'statsmodels.api' library

# %%
import statsmodels.api as sm
x_sm = sm.add_constant(X)
sm_model = sm.OLS(y, x_sm).fit()

# %%
sm_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Number of fertile tillers    R-squared:                       0.835
# Model:                                    OLS   Adj. R-squared:                  0.833
# Method:                         Least Squares   F-statistic:                     319.9
# Date:                        Sun, 06 Jul 2025   Prob (F-statistic):          1.32e-168
# Time:                                13:43:23   Log-Likelihood:                -1249.7
# No. Observations:                         450   AIC:                             2515.
# Df Residuals:                             442   BIC:                             2548.
# Df Model:                                   7
# Covariance Type:                    nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        4.3292      1.745      2.480      0.013       0.899       7.760
# Leaf blade length [cm]      -0.0706      0.025     -2.860      0.004      -0.119      -0.022
# Leaf blade width [cm]        0.9221      0.626      1.473      0.142      -0.308       2.153
# Culm length [cm]            -0.0119      0.011     -1.108      0.268      -0.033       0.009
# Panicle length [cm]         -0.0692      0.065     -1.069      0.286      -0.196       0.058
# Ligule length [mm]           1.4419      0.293      4.927      0.000       0.867       2.017
# Culm diameter [mm]          -0.1678      0.096     -1.742      0.082      -0.357       0.022
# Total number of tillers      0.7352      0.017     44.173      0.000       0.702       0.768
# ==============================================================================
# Omnibus:                      172.600   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19303.378
# Skew:                           0.550   Prob(JB):                         0.00
# Kurtosis:                      35.067   Cond. No.                     1.10e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Linear regression explained 83.5% of the variance in the variable "Number of fertile tillers" (R² = 0.835).
#
# -A 1 cm increase in Leaf blade length is associated with a 0.0706 unit decrease in Number of fertile tillers
#
# -A 1 mm increase in Ligule length is associated with a 1.4419 unit increase in Number of fertile tillers
#
# -Each additional unit in Total number of tillers is associated with a 0.7352 unit increase in Number of fertile tillers
